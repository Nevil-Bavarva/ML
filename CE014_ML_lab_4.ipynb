# %%
import numpy as np
import torch
import random

inputs = np.array([[73, 67, 43],
[91, 88, 64],
[87, 134, 58],
[102, 43, 37],
[69, 96, 70]], dtype='float32')

targets = np.array([[56],
[81],
[119],
[22],
[103]], dtype='float32')

tensor_inputs = torch.from_numpy(inputs)
tensor_targets = torch.from_numpy(targets)

# print(tensor_inputs)
# print(tensor_targets)


weight = torch.randn(1,3)
biases = torch.randn(1,1)

# print(biases)

transposed_weight = torch.transpose(weight,0,1)
# print(transposed_weight)

def linear_model(transposed_weight, biases, tensor_inputs):
  prediction_values=torch.matmul(tensor_inputs,(transposed_weight + biases))
  
  # prediction_values_temp = torch.matmul(tensor_inputs,transposed_weight)
  # predict = prediction_values_temp + biases
  # print("temp _ ", predict)
  
  
  return prediction_values

print(linear_model(transposed_weight,biases, tensor_inputs))
